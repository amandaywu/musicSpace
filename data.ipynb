# %%
from collections import defaultdict
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
#import lyricsgenius

# %% [markdown]
# ## Get Audio Features

# %%
#top200 = pd.read_csv("regional-global-daily-latest.csv")
#top100 = top200[:100]
SPOTIPY_CLIENT_ID='f080ca9eb9af4dcb9b5d37612913e1b0'
SPOTIPY_CLIENT_SECRET='05993585eab249dc96eef558c9c099c9'
client_credentials_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# for key, value in sp.audio_features("https://open.spotify.com/track/127QTOFJsJQp5LbJbu3A1y")[0].items():
#     print(key, value)

# %%
audio_features = defaultdict(list)
for song in top100["URL"]:
    results = sp.audio_features(song)[0]
    for key, value in results.items():
        audio_features[key].append(value)

for key, value in audio_features.items():
    top100[key] = value

# %%
old_town_road_URI = "spotify:track:0F7FA14euOIX8KcbEturGH"
sp.audio_features(old_town_road_URI)
# Out:
# [{'danceability': 0.907,
#   'energy': 0.53,
#   'key': 1,
#   'loudness': -6.112,
#   'mode': 1,
#   'speechiness': 0.127,
#   'acousticness': 0.0578,
#   'instrumentalness': 2.23e-06,
#   'liveness': 0.101,
#   'valence': 0.507,
#   'tempo': 135.998,
#   'type': 'audio_features',
#   'id': '0F7FA14euOIX8KcbEturGH',
#   'uri': 'spotify:track:0F7FA14euOIX8KcbEturGH',
#   'track_href': 'https://api.spotify.com/v1/tracks/0F7FA14euOIX8KcbEturGH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0F7FA14euOIX8KcbEturGH',
#   'duration_ms': 113000,
#   'time_signature': 4}]

# %%
import json 

dictionary = sp.audio_analysis(old_town_road_URI)
json_object = json.dumps(dictionary, indent = 4)

with open("old_town_road_audio_analysis.json", "w") as outfile: 
    outfile.write(json_object)

# %% [markdown]
# ## Get Lyrics

# %%
GENIUS_CLIENT_TOKEN = "BM1IRnK-WWweAWplQAv5wOaqPRaY2j0s2XKmiTutVHombPr9bNbeOZKemOXladmR"
genius = lyricsgenius.Genius(GENIUS_CLIENT_TOKEN)

# %%
lyrics = []
for song in top100.iterrows():
    track_name, artist_name = song[1]["Track Name"], song[1]["Artist"]
    result = genius.search_song(track_name, artist_name)
    if result:
        lyrics.append(result.lyrics)
    else:
        lyrics.append(None)
# Out:
# Searching for "Toosie Slide" by Drake...
# Done.
# Searching for "Blinding Lights" by The Weeknd...
# Done.
# Searching for "Roses - Imanbek Remix" by SAINt JHN...
# Done.
# Searching for "Don't Start Now" by Dua Lipa...
# Done.
# Searching for "The Box" by Roddy Ricch...
# Done.
# Searching for "death bed (coffee for your head) (feat. beabadoobee)" by Powfu...
# Done.
# Searching for "Dance Monkey" by Tones And I...
# Done.
# Searching for "Blueberry Faygo" by Lil Mosey...
# Done.
# Searching for "Say So" by Doja Cat...
# Done.
# Searching for "Break My Heart" by Dua Lipa...
# Done.
# Searching for "Intentions (feat. Quavo)" by Justin Bieber...
# Done.
# Searching for "Falling" by Trevor Daniel...
# Done.
# Searching for "Supalonely" by BENEE...
# Done.
# Searching for "Sunday Best" by Surfaces...
# Done.
# Searching for "In Your Eyes" by The Weeknd...
# Done.
# Searching for "Safaera" by Bad Bunny...
# Done.
# Searching for "Savage" by Megan Thee Stallion...
# Done.
# ...

# %%
top100 = top200[:100]
top100["lyrics"] = lyrics[:100]
top100.head()
top100.to_csv("top100_songs_features.csv", index=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
